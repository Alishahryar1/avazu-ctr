# %% [markdown]
# # Dataset report
#
# This notebook is a thin consumer of the package-owned report generator.

# %%
from avazu_ctr.exploration import dataset_report

dataset_report(
    "artifacts/datasets/senet-dcnv2-multihead/final_holdout/manifest.json",
    "artifacts/reports/dataset",
)
