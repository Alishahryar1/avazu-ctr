# %% [markdown]
# # Experiment comparison
#
# SQLite remains authoritative; this notebook only renders its recorded runs.

# %%
from avazu_ctr.exploration import run_report

run_report("artifacts/experiments.sqlite3", "artifacts/reports/runs")
